# %%
import numpy as np
import pandas as pd
import random

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# data=pd.read_csv("/content/drive/MyDrive/MTP Data/MTP DATA - BOD.csv")
# data = data.sample(frac = 1)

# %%
data=pd.read_csv("/content/dod_1.csv")
data = data.sample(frac = 1)

# %%
# data.to_csv('dod_1.csv')

# %%
data.head(10)
# Out:
#    Type of Wastewater  Temperature (C)    pH  VF Area (m2)  HF Area (m2)  \
# 10             Cheese             30.0  4.30        360.00         180.0
# 21             Sewage             23.0   NaN         13.70          18.0
# 6              Cheese             30.0  4.81        360.00         180.0
# 27             Sewage              NaN   NaN          2.54           6.0
# 5              Sewage             20.0  7.00        150.00         300.0
# 29            Tannery              8.4   NaN          0.65           1.3
# 18             Winery             20.9  6.28         50.00         300.0
# 31             Sewage              NaN   NaN        850.00         750.0
# 35        Aquaculture             17.0  8.00         16.00          16.0
# 12  Landfill leachate             15.3  7.30         41.00         270.0
#
#       HRT (d)  HLR (L/m2d)  Q (flow) (m3/d)  Influent Conc. (mg/L)  \
# 10   4.000000   100.000000            17.00                 1450.0
# 21   1.400000    63.000000             3.00                   84.0
# 6    4.000000   100.000000            17.00                 1592.0
# 27        NaN    18.100000             8.00                  191.0
# 5    0.416667    41.666667            12.50                  409.0
# 29  12.500000     6.000000              NaN                 4200.0
# 18        NaN    19.500000            17.30                  520.0
# 31        NaN          NaN              NaN                 1620.0
# 35   0.085000     1.950000            53.90                    7.1
# 12   7.330000    50.000000             1.72                   78.0
#
#     Effluent Conc. (mg/L)  Removal Efficiency (%)
# 10                  760.0                    47.6
# 21                    8.0                    90.0
# 6                   717.0                    55.0
# 27                   11.0                    94.2
# 5                    66.0                    84.0
# 29                   80.0                    98.0
# 18                   71.0                    86.0
# 31                   45.0                    97.0
# 35                    2.5                    54.0
# 12                   28.0                    63.0

# %%
data.tail(10)
# Out:
#      Type of Wastewater  Temperature (C)    pH  VF Area (m2)  HF Area (m2)  \
# 25               Sewage              NaN   NaN          2.54           6.0
# 41  Domestic Wastewater             20.0  7.30        100.00         100.0
# 15               Winery             17.9  5.84         50.00         300.0
# 0                Sewage              NaN   NaN       1500.00         750.0
# 36         Agriculture              22.0  7.20        100.00         100.0
# 40  Domestic Wastewater             20.0  7.60         10.00          10.0
# 9                Cheese             30.0  6.70        360.00         180.0
# 26               Sewage              NaN   NaN          2.54           6.0
# 23      Slaughter House             12.6   NaN         10.00          15.0
# 43  Domestic Wastewater             22.0  7.50        100.00         100.0
#
#     HRT (d)  HLR (L/m2d)  Q (flow) (m3/d)  Influent Conc. (mg/L)  \
# 25      NaN         89.0             2.20                   88.0
# 41     10.0          1.0             1.00                  150.0
# 15      NaN         19.5            17.30                 1339.0
# 0       2.0          NaN           184.00                   72.0
# 36     10.0          1.5             1.50                  200.0
# 40     10.0          1.0             1.00                  250.0
# 9       4.0        100.0            17.00                 1350.0
# 26      NaN          7.7             4.00                   73.0
# 23      NaN         15.0             0.15                 2452.0
# 43     10.0          1.5            10.00                  170.0
#
#     Effluent Conc. (mg/L)  Removal Efficiency (%)
# 25                   19.0                   78.40
# 41                    5.7                   96.30
# 15                  441.0                   67.00
# 0                     5.8                   92.00
# 36                    9.0                   95.62
# 40                   42.0                   84.00
# 9                   750.0                   44.50
# 26                   16.0                   78.10
# 23                    4.0                   99.84
# 43                   11.0                   93.70

# %%
data.sample(5)
# Out:
#      Type of Wastewater  Temperature (C)   pH  VF Area (m2)  HF Area (m2)  \
# 22               Sewage             17.0  NaN          13.7          18.0
# 2                Sewage              NaN  NaN           0.6           1.2
# 44  Domestic Wastewater             25.0  7.0          50.0          50.0
# 36         Agriculture              22.0  7.2         100.0         100.0
# 23      Slaughter House             12.6  NaN          10.0          15.0
#
#     HRT (d)  HLR (L/m2d)  Q (flow) (m3/d)  Influent Conc. (mg/L)  \
# 22      1.4        126.0            3.000                   61.0
# 2       NaN        240.0            0.144                  420.0
# 44      5.0          2.0            1.000                  180.0
# 36     10.0          1.5            1.500                  200.0
# 23      NaN         15.0            0.150                 2452.0
#
#     Effluent Conc. (mg/L)  Removal Efficiency (%)
# 22                    6.0                   90.00
# 2                    30.0                   93.00
# 44                   10.0                   94.30
# 36                    9.0                   95.62
# 23                    4.0                   99.84

# %%
data.shape
# Out:
# (45, 11)

# %%
data.describe()
# Out:
#        Temperature (C)         pH  VF Area (m2)  HF Area (m2)    HRT (d)  \
# count        34.000000  28.000000     45.000000     45.000000  30.000000
# mean         21.541176   6.701071    148.794889    164.469778   4.749833
# std           5.939754   1.194926    264.084790    217.405312   3.871176
# min           8.400000   3.900000      0.210000      0.670000   0.085000
# 25%          17.925000   6.230000     10.000000     13.300000   1.400000
# 50%          22.000000   7.000000     50.000000    100.000000   4.000000
# 75%          25.000000   7.400000    160.000000    216.000000   7.247500
# max          30.000000   9.110000   1500.000000   1050.000000  12.500000
#
#        HLR (L/m2d)  Q (flow) (m3/d)  Influent Conc. (mg/L)  \
# count    43.000000        42.000000              45.000000
# mean     44.352016        19.096571             698.428889
# std      52.136155        40.479209            1118.022907
# min       1.000000         0.066000               3.100000
# 25%       2.000000         1.062500             114.000000
# 50%      19.500000         9.000000             220.000000
# 75%      72.835000        17.300000             859.000000
# max     240.000000       197.000000            5880.000000
#
#        Effluent Conc. (mg/L)  Removal Efficiency (%)
# count              45.000000               45.000000
# mean              142.197778               81.357111
# std               275.554205               18.864613
# min                 1.900000               31.250000
# 25%                 8.000000               78.100000
# 50%                19.000000               87.660000
# 75%                71.000000               94.800000
# max              1160.000000               99.840000

# %%
data.describe(include="all")
# Out:
#        Type of Wastewater  Temperature (C)         pH  VF Area (m2)  \
# count                  45        34.000000  28.000000     45.000000
# unique                  9              NaN        NaN           NaN
# top                Sewage              NaN        NaN           NaN
# freq                   18              NaN        NaN           NaN
# mean                  NaN        21.541176   6.701071    148.794889
# std                   NaN         5.939754   1.194926    264.084790
# min                   NaN         8.400000   3.900000      0.210000
# 25%                   NaN        17.925000   6.230000     10.000000
# 50%                   NaN        22.000000   7.000000     50.000000
# 75%                   NaN        25.000000   7.400000    160.000000
# max                   NaN        30.000000   9.110000   1500.000000
#
#         HF Area (m2)    HRT (d)  HLR (L/m2d)  Q (flow) (m3/d)  \
# count      45.000000  30.000000    43.000000        42.000000
# unique           NaN        NaN          NaN              NaN
# top              NaN        NaN          NaN              NaN
# freq             NaN        NaN          NaN              NaN
# mean      164.469778   4.749833    44.352016        19.096571
# std       217.405312   3.871176    52.136155        40.479209
# min         0.670000   0.085000     1.000000         0.066000
# 25%        13.300000   1.400000     2.000000         1.062500
# 50%       100.000000   4.000000    19.500000         9.000000
# 75%       216.000000   7.247500    72.835000        17.300000
# max      1050.000000  12.500000   240.000000       197.000000
#
#         Influent Conc. (mg/L)  Effluent Conc. (mg/L)  Removal Efficiency (%)
# count               45.000000              45.000000               45.000000
# unique                    NaN                    NaN                     NaN
# top                       NaN                    NaN                     NaN
# freq                      NaN                    NaN                     NaN
# mean               698.428889             142.197778               81.357111
# std               1118.022907             275.554205               18.864613
# min                  3.100000               1.900000               31.250000
# 25%                114.000000               8.000000               78.100000
# 50%                220.000000              19.000000               87.660000
# 75%                859.000000              71.000000               94.800000
# max               5880.000000            1160.000000               99.840000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45 entries, 10 to 43
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Type of Wastewater      45 non-null     object
#  1   Temperature (C)         34 non-null     float64
#  2   pH                      28 non-null     float64
#  3   VF Area (m2)            45 non-null     float64
#  4   HF Area (m2)            45 non-null     float64
#  5   HRT (d)                 30 non-null     float64
#  6   HLR (L/m2d)             43 non-null     float64
#  7   Q (flow) (m3/d)         42 non-null     float64
#  8   Influent Conc. (mg/L)   45 non-null     float64
#  9   Effluent Conc. (mg/L)   45 non-null     float64
#  10  Removal Efficiency (%)  45 non-null     float64
# dtypes: float64(10), object(1)
# memory usage: 4.2+ KB

# %%
data.isnull()
# Out:
#     Type of Wastewater  Temperature (C)     pH  VF Area (m2)  HF Area (m2)  \
# 10               False            False  False         False         False
# 21               False            False   True         False         False
# 6                False            False  False         False         False
# 27               False             True   True         False         False
# 5                False            False  False         False         False
# 29               False            False   True         False         False
# 18               False            False  False         False         False
# 31               False             True   True         False         False
# 35               False            False  False         False         False
# 12               False            False  False         False         False
# 39               False            False  False         False         False
# 38               False            False  False         False         False
# 3                False            False   True         False         False
# 37               False            False  False         False         False
# 24               False             True   True         False         False
# 34               False            False  False         False         False
# 17               False            False  False         False         False
# 4                False            False   True         False         False
# 16               False            False  False         False         False
# 44               False            False  False         False         False
# 1                False             True   True         False         False
# 33               False             True   True         False         False
# 42               False            False  False         False         False
# 11               False            False  False         False         False
# 20               False             True   True         False         False
# 22               False            False   True         False         False
# 32               False            False  False         False         False
# 7                False            False  False         False         False
# 8                False            False  False         False         False
# 28               False             True   True         False         False
# 2                False             True   True         False         False
# 19               False            False  False         False         False
# 13               False            False  False         False         False
# 30               False            False  False         False         False
# 14               False            False  False         False         False
# 25               False             True   True         False         False
# 41               False            False  False         False         False
# 15               False            False  False         False         False
# 0                False             True   True         False         False
# 36               False            False  False         False         False
# 40               False            False  False         False         False
# 9                False            False  False         False         False
# 26               False             True   True         False         False
# 23               False            False   True         False         False
# 43               False            False  False         False         False
#
#     HRT (d)  HLR (L/m2d)  Q (flow) (m3/d)  Influent Conc. (mg/L)  \
# 10    False        False            False                  False
# 21    False        False            False                  False
# 6     False        False            False                  False
# 27     True        False            False                  False
# 5     False        False            False                  False
# 29    False        False             True                  False
# 18     True        False            False                  False
# 31     True         True             True                  False
# 35    False        False            False                  False
# 12    False        False            False                  False
# 39    False        False            False                  False
# 38    False        False            False                  False
# 3     False        False            False                  False
# 37    False        False            False                  False
# 24     True        False            False                  False
# 34    False        False            False                  False
# 17     True        False            False                  False
# 4     False        False            False                  False
# 16     True        False            False                  False
# 44    False        False            False                  False
# 1      True        False            False                  False
# 33    False        False             True                  False
# 42    False        False            False                  False
# 11    False        False            False                  False
# 20    False        False            False                  False
# 22    False        False            False                  False
# 32    False        False            False                  False
# 7     False        False            False                  False
# 8     False        False            False                  False
# 28     True        False            False                  False
# 2      True        False            False                  False
# 19    False        False            False                  False
# 13     True        False            False                  False
# 30    False        False            False                  False
# 14     True        False            False                  False
# 25     True        False            False                  False
# 41    False        False            False                  False
# 15     True        False            False                  False
# 0     False         True            False                  False
# 36    False        False            False                  False
# 40    False        False            False                  False
# 9     False        False            False                  False
# 26     True        False            False                  False
# 23     True        False            False                  False
# 43    False        False            False                  False
#
#     Effluent Conc. (mg/L)  Removal Efficiency (%)
# 10                  False                   False
# 21                  False                   False
# 6                   False                   False
# 27                  False                   False
# 5                   False                   False
# 29                  False                   False
# 18                  False                   False
# 31                  False                   False
# 35                  False                   False
# 12                  False                   False
# 39                  False                   False
# 38                  False                   False
# 3                   False                   False
# 37                  False                   False
# 24                  False                   False
# 34                  False                   False
# 17                  False                   False
# 4                   False                   False
# 16                  False                   False
# 44                  False                   False
# 1                   False                   False
# 33                  False                   False
# 42                  False                   False
# 11                  False                   False
# 20                  False                   False
# 22                  False                   False
# 32                  False                   False
# 7                   False                   False
# 8                   False                   False
# 28                  False                   False
# 2                   False                   False
# 19                  False                   False
# 13                  False                   False
# 30                  False                   False
# 14                  False                   False
# 25                  False                   False
# 41                  False                   False
# 15                  False                   False
# 0                   False                   False
# 36                  False                   False
# 40                  False                   False
# 9                   False                   False
# 26                  False                   False
# 23                  False                   False
# 43                  False                   False

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(20, 10))

cmap = sns.cubehelix_palette(light=1, as_cmap=True, reverse=True)
sns.heatmap(data.isnull(), cmap=cmap)
# Out:
# <Axes: >

# %%
data.isnull().sum()
# Out:
# Type of Wastewater         0
# Temperature (C)           11
# pH                        17
# VF Area (m2)               0
# HF Area (m2)               0
# HRT (d)                   15
# HLR (L/m2d)                2
# Q (flow) (m3/d)            3
# Influent Conc. (mg/L)      0
# Effluent Conc. (mg/L)      0
# Removal Efficiency (%)     0
# dtype: int64

# %%
data.dtypes
# Out:
# Type of Wastewater         object
# Temperature (C)           float64
# pH                        float64
# VF Area (m2)              float64
# HF Area (m2)              float64
# HRT (d)                   float64
# HLR (L/m2d)               float64
# Q (flow) (m3/d)           float64
# Influent Conc. (mg/L)     float64
# Effluent Conc. (mg/L)     float64
# Removal Efficiency (%)    float64
# dtype: object

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data.hist(figsize=(30,30))
# Out:
# array([[<Axes: title={'center': 'Temperature (C)'}>,
#         <Axes: title={'center': 'pH'}>,
#         <Axes: title={'center': 'VF Area (m2)'}>],
#        [<Axes: title={'center': 'HF Area (m2)'}>,
#         <Axes: title={'center': 'HRT (d)'}>,
#         <Axes: title={'center': 'HLR (L/m2d)'}>],
#        [<Axes: title={'center': 'Q (flow) (m3/d)'}>,
#         <Axes: title={'center': 'Influent Conc. (mg/L)'}>,
#         <Axes: title={'center': 'Effluent Conc. (mg/L)'}>],
#        [<Axes: title={'center': 'Removal Efficiency (%)'}>, <Axes: >,
#         <Axes: >]], dtype=object)

# %%
import seaborn as sns
sns.boxplot(x="Removal Efficiency (%)", data=data)
# Out:
# <Axes: xlabel='Removal Efficiency (%)'>

# %%
sns.boxplot(x="Influent Conc. (mg/L)",data=data)
# Out:
# <Axes: xlabel='Influent Conc. (mg/L)'>

# %%
sns.boxplot(x="Effluent Conc. (mg/L)",data=data)
# Out:
# <Axes: xlabel='Effluent Conc. (mg/L)'>

# %%
sns.pairplot(data)

# %%
sns.pairplot(data,diag_kind='kde')

# %%
sns.catplot(x="Influent Conc. (mg/L)", y="Removal Efficiency (%)", kind="point", height=5, aspect=2, data=data)

# %%
sns.catplot(x="HLR (L/m2d)", y="Removal Efficiency (%)", kind="point", aspect = 2 , data=data)

# %%
sns.catplot(x="Q (flow) (m3/d)", y="Removal Efficiency (%)", kind="point", aspect = 2 , data=data)

# %%
sns.catplot(x="HRT (d)", y="Removal Efficiency (%)", kind="point", aspect = 2 , data=data)

# %%
sns.catplot(x="Temperature (C)", y="Removal Efficiency (%)", kind="point", aspect=2 , data=data)

# %%
sns.catplot(x="pH", y="Removal Efficiency (%)", kind="point", aspect=2 , data=data)

# %%
sns.catplot(x="VF Area (m2)", y="Removal Efficiency (%)", kind="point" , data=data)

# %%
sns.catplot(x="HF Area (m2)", y="Removal Efficiency (%)", kind="point" , data=data)

# %%
sns.lmplot(x="Influent Conc. (mg/L)", y="Removal Efficiency (%)", data=data);

# %%
sns.lmplot(x="HLR (L/m2d)", y="Removal Efficiency (%)", data=data);

# %%
sns.lmplot(x="HRT (d)", y="Removal Efficiency (%)", data=data);

# %%
sns.lmplot(x="Q (flow) (m3/d)", y="Removal Efficiency (%)", data=data);

# %%
sns.lmplot(x="Temperature (C)", y="Removal Efficiency (%)", data=data);

# %%
sns.lmplot(x="pH", y="Removal Efficiency (%)", data=data);

# %%
sns.lmplot(x="VF Area (m2)", y="Removal Efficiency (%)", data=data);

# %%
data
# Out:
#      Type of Wastewater  Temperature (C)    pH  VF Area (m2)  HF Area (m2)  \
# 10               Cheese             30.0  4.30        360.00        180.00
# 21               Sewage             23.0   NaN         13.70         18.00
# 6                Cheese             30.0  4.81        360.00        180.00
# 27               Sewage              NaN   NaN          2.54          6.00
# 5                Sewage             20.0  7.00        150.00        300.00
# 29              Tannery              8.4   NaN          0.65          1.30
# 18               Winery             20.9  6.28         50.00        300.00
# 31               Sewage              NaN   NaN        850.00        750.00
# 35          Aquaculture             17.0  8.00         16.00         16.00
# 12    Landfill leachate             15.3  7.30         41.00        270.00
# 39  Domestic Wastewater             23.0  7.30          5.00          5.00
# 38  Domestic Wastewater             25.0  7.20         50.00         50.00
# 3                Sewage             18.0   NaN          0.21          0.67
# 37  Domestic Wastewater             20.5  7.40        100.00        100.00
# 24               Sewage              NaN   NaN          2.54          6.00
# 34          Aquaculture             28.0  7.80         16.00         16.00
# 17               Winery             12.5  6.08         50.00        300.00
# 4                Sewage             24.5   NaN          0.21          0.67
# 16               Winery             11.5  6.44         50.00        300.00
# 44  Domestic Wastewater             25.0  7.00         50.00         50.00
# 1                Sewage              NaN   NaN        216.00        216.00
# 33          Aquaculture              NaN   NaN        160.00        160.00
# 42  Domestic Wastewater             25.0  7.40         70.00         70.00
# 11               Cheese             30.0  3.90        360.00        180.00
# 20               Sewage              NaN   NaN        150.00        150.00
# 22               Sewage             17.0   NaN         13.70         18.00
# 32               Sewage             22.5  7.00          8.00         13.30
# 7                Cheese             30.0  9.11        360.00        180.00
# 8                Cheese             30.0  4.30        360.00        180.00
# 28               Sewage              NaN   NaN          2.54          6.00
# 2                Sewage              NaN   NaN          0.60          1.20
# 19               Sewage             20.0  7.50        180.00        160.00
# 13               Winery             24.2  6.51         50.00        300.00
# 30               Sewage             12.7  6.90        312.00       1050.00
# 14               Winery             23.9  5.96         50.00        300.00
# 44                   10.0                   94.30
# 1                     5.5                   94.00
# 33                    1.9                   56.00
# 42                   11.4                   94.20
# 11                 1160.0                   80.00
# 20                  173.0                   78.00
# 22                    6.0                   90.00
# 32                    2.2                   98.00
# 7                   800.0                   41.00
# 8                   550.0                   31.25
# 28                   10.0                   94.50
# 2                    30.0                   93.00
# 19                    2.0                   95.00
# 13                  106.0                   87.66
# 30                    6.7                   98.00
# 14                   59.0                   95.00
# 25                   19.0                   78.40
# 41                    5.7                   96.30
# 15                  441.0                   67.00
# 0                     5.8                   92.00
# 36                    9.0                   95.62
# 40                   42.0                   84.00
# 9                   750.0                   44.50
# 26                   16.0                   78.10
# 23                    4.0                   99.84
# 43                   11.0                   93.70

# %%
sns.lmplot(x="HF Area (m2)", y="Removal Efficiency (%)", data=data);

# %%
corr=data.corr()
corr
# Out:
# <ipython-input-204-0d3ae1d0be10>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=data.corr()
#                         Temperature (C)        pH  VF Area (m2)  HF Area (m2)  \
# Temperature (C)                1.000000 -0.291895      0.548282     -0.205427
# pH                            -0.291895  1.000000     -0.466927     -0.188391
# VF Area (m2)                   0.548282 -0.466927      1.000000      0.672411
# HF Area (m2)                  -0.205427 -0.188391      0.672411      1.000000
# HRT (d)                       -0.398654  0.121049     -0.107281      0.197990
# HLR (L/m2d)                    0.386217 -0.383370      0.322188     -0.072873
# Q (flow) (m3/d)                0.046491  0.037138      0.556277      0.302369
# Influent Conc. (mg/L)          0.055602 -0.629780      0.153562      0.064444
# Effluent Conc. (mg/L)          0.581752 -0.582742      0.278823      0.068087
# Removal Efficiency (%)        -0.501274  0.207628     -0.114347      0.063953
#
#                          HRT (d)  HLR (L/m2d)  Q (flow) (m3/d)  \
# Temperature (C)        -0.398654     0.386217         0.046491
# pH                      0.121049    -0.383370         0.037138
# VF Area (m2)           -0.107281     0.322188         0.556277
# HF Area (m2)            0.197990    -0.072873         0.302369
# HRT (d)                 1.000000    -0.418518        -0.237127
# HLR (L/m2d)            -0.418518     1.000000         0.053806
# Q (flow) (m3/d)        -0.237127     0.053806         1.000000
# Influent Conc. (mg/L)   0.162703     0.144296        -0.074202
# Effluent Conc. (mg/L)  -0.104479     0.397501        -0.039230
# Removal Efficiency (%)  0.392514    -0.221300         0.005735
#
#                         Influent Conc. (mg/L)  Effluent Conc. (mg/L)  \
# Temperature (C)                      0.055602               0.581752
# pH                                  -0.629780              -0.582742
# VF Area (m2)                         0.153562               0.278823
# HF Area (m2)                         0.064444               0.068087
# HRT (d)                              0.162703              -0.104479
# HLR (L/m2d)                          0.144296               0.397501
# Q (flow) (m3/d)                     -0.074202              -0.039230
# Influent Conc. (mg/L)                1.000000               0.648661
# Effluent Conc. (mg/L)                0.648661               1.000000
# Removal Efficiency (%)              -0.060844              -0.590286
#
#                         Removal Efficiency (%)
# Temperature (C)                      -0.501274
# pH                                    0.207628
# VF Area (m2)                         -0.114347
# HF Area (m2)                          0.063953
# HRT (d)                               0.392514
# HLR (L/m2d)                          -0.221300
# Q (flow) (m3/d)                       0.005735
# Influent Conc. (mg/L)                -0.060844
# Effluent Conc. (mg/L)                -0.590286
# Removal Efficiency (%)                1.000000

# %%
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
data.head()
# Out:
#    Type of Wastewater  Temperature (C)    pH  VF Area (m2)  HF Area (m2)  \
# 10             Cheese             30.0  4.30        360.00         180.0
# 21             Sewage             23.0   NaN         13.70          18.0
# 6              Cheese             30.0  4.81        360.00         180.0
# 27             Sewage              NaN   NaN          2.54           6.0
# 5              Sewage             20.0  7.00        150.00         300.0
#
#      HRT (d)  HLR (L/m2d)  Q (flow) (m3/d)  Influent Conc. (mg/L)  \
# 10  4.000000   100.000000             17.0                 1450.0
# 21  1.400000    63.000000              3.0                   84.0
# 6   4.000000   100.000000             17.0                 1592.0
# 27       NaN    18.100000              8.0                  191.0
# 5   0.416667    41.666667             12.5                  409.0
#
#     Effluent Conc. (mg/L)  Removal Efficiency (%)
# 10                  760.0                    47.6
# 21                    8.0                    90.0
# 6                   717.0                    55.0
# 27                   11.0                    94.2
# 5                    66.0                    84.0

# %%
data.isnull().sum()
# Out:
# Type of Wastewater         0
# Temperature (C)           11
# pH                        17
# VF Area (m2)               0
# HF Area (m2)               0
# HRT (d)                   15
# HLR (L/m2d)                2
# Q (flow) (m3/d)            3
# Influent Conc. (mg/L)      0
# Effluent Conc. (mg/L)      0
# Removal Efficiency (%)     0
# dtype: int64

# %%
features=['Temperature (C)','pH','HRT (d)','HLR (L/m2d)','Q (flow) (m3/d)']

for feature in features:
  data[feature].fillna(data[feature].median(),inplace=True)

# %%
data.isnull().sum()
# Out:
# Type of Wastewater        0
# Temperature (C)           0
# pH                        0
# VF Area (m2)              0
# HF Area (m2)              0
# HRT (d)                   0
# HLR (L/m2d)               0
# Q (flow) (m3/d)           0
# Influent Conc. (mg/L)     0
# Effluent Conc. (mg/L)     0
# Removal Efficiency (%)    0
# dtype: int64

# %%
import seaborn as sns
sns.boxplot(x="Influent Conc. (mg/L)", data=data)
# Out:
# <Axes: xlabel='Influent Conc. (mg/L)'>

# %%
data['Influent Conc. (mg/L)'].describe()
# Out:
# count      45.000000
# mean      698.428889
# std      1118.022907
# min         3.100000
# 25%       114.000000
# 50%       220.000000
# 75%       859.000000
# max      5880.000000
# Name: Influent Conc. (mg/L), dtype: float64

# %%
df1=data[data['Influent Conc. (mg/L)']>8000]
df2=data[data['Influent Conc. (mg/L)']<=8000]

df1['Influent Conc. (mg/L)']=8000
data=pd.concat([df1,df2])

# %%
sns.boxplot(x="Influent Conc. (mg/L)", data=data)
# Out:
# <Axes: xlabel='Influent Conc. (mg/L)'>

# %%
df1=data.copy()

# %%
df1.dtypes
# Out:
# Type of Wastewater         object
# Temperature (C)           float64
# pH                        float64
# VF Area (m2)              float64
# HF Area (m2)              float64
# HRT (d)                   float64
# HLR (L/m2d)               float64
# Q (flow) (m3/d)           float64
# Influent Conc. (mg/L)     float64
# Effluent Conc. (mg/L)     float64
# Removal Efficiency (%)    float64
# dtype: object

# %%
df1.dropna(subset=['Effluent Conc. (mg/L)'],inplace=True)

# %%
df1
# Out:
#      Type of Wastewater  Temperature (C)    pH  VF Area (m2)  HF Area (m2)  \
# 10               Cheese             30.0  4.30        360.00        180.00
# 21               Sewage             23.0  7.00         13.70         18.00
# 6                Cheese             30.0  4.81        360.00        180.00
# 27               Sewage             22.0  7.00          2.54          6.00
# 5                Sewage             20.0  7.00        150.00        300.00
# 29              Tannery              8.4  7.00          0.65          1.30
# 33   1.100000     2.810000            9.000                    4.3
# 42   7.000000     1.500000            1.050                  200.0
# 11   4.000000   100.000000           17.000                 5880.0
# 20   0.230000    66.670000           10.000                  774.0
# 22   1.400000   126.000000            3.000                   61.0
# 32   3.300000    66.000000          197.000                  114.0
# 7    4.000000   100.000000           17.000                 1350.0
# 8    4.000000   100.000000           17.000                  800.0
# 28   4.000000    29.500000            1.100                  182.0
# 2    4.000000   240.000000            0.144                  420.0
# 19   3.000000   160.000000           25.000                   41.0
# 13   4.000000    19.500000           17.300                  859.0
# 30  12.300000    19.500000           20.500                  324.0
# 14   4.000000    19.500000           17.300                 1243.0
# 25   4.000000    89.000000            2.200                   88.0
# 41  10.000000     1.000000            1.000                  150.0
# 15   4.000000    19.500000           17.300                 1339.0
# 0    2.000000    19.500000          184.000                   72.0
# 36  10.000000     1.500000            1.500                  200.0
# 40  10.000000     1.000000            1.000                  250.0
# 9    4.000000   100.000000           17.000                 1350.0
# 26   4.000000     7.700000            4.000                   73.0
# 23   4.000000    15.000000            0.150                 2452.0
# 43  10.000000     1.500000           10.000                  170.0
#
#     Effluent Conc. (mg/L)  Removal Efficiency (%)
# 10                  760.0                   47.60
# 21                    8.0                   90.00
# 6                   717.0                   55.00
# 27                   11.0                   94.20
# 5                    66.0                   84.00
# 29                   80.0                   98.00
# 18                   71.0                   86.00
# 31                   45.0                   97.00
# 35                    2.5                   54.00
# 12                   28.0                   63.00
# 39                    8.0                   96.50
# 38                   10.3                   94.80
# 3                    24.0                   85.00
# 37                    8.0                   96.40
# 24                   51.0                   79.20
# 34                    1.9                   37.00
# 17                   28.0                   87.00
# 4                    40.0                   87.00
# 16                  202.0                   80.00
# 44                   10.0                   94.30
# 1                     5.5                   94.00
# 33                    1.9                   56.00
# 42                   11.4                   94.20
# 11                 1160.0                   80.00
# 20                  173.0                   78.00
# 22                    6.0                   90.00
# 32                    2.2                   98.00
# 7                   800.0                   41.00
# 8                   550.0                   31.25
# 28                   10.0                   94.50
# 2                    30.0                   93.00
# 19                    2.0                   95.00
# 13                  106.0                   87.66
# 30                    6.7                   98.00
# 14                   59.0                   95.00
# 25                   19.0                   78.40
# 41                    5.7                   96.30
# 15                  441.0                   67.00
# 0                     5.8                   92.00
# 36                    9.0                   95.62
# 40                   42.0                   84.00
# 9                   750.0                   44.50
# 26                   16.0                   78.10
# 23                    4.0                   99.84
# 43                   11.0                   93.70

# %%
one_hot_encoded_data = pd.get_dummies(df1, columns = ['Type of Wastewater'])
df1.drop(['Type of Wastewater'],axis=1,inplace=True)
df1 = df1.merge(one_hot_encoded_data)

# %%
df1.drop(['Type of Wastewater_Agriculture '],axis=1,inplace=True)

# %%
df1.columns
# Out:
# Index(['Temperature (C)', 'pH', 'VF Area (m2)', 'HF Area (m2)', 'HRT (d)',
#        'HLR (L/m2d)', 'Q (flow) (m3/d)', 'Influent Conc. (mg/L)',
#        'Effluent Conc. (mg/L)', 'Removal Efficiency (%)',
#        'Type of Wastewater_Aquaculture', 'Type of Wastewater_Cheese',
#        'Type of Wastewater_Domestic Wastewater',
#        'Type of Wastewater_Landfill leachate', 'Type of Wastewater_Sewage',
#        'Type of Wastewater_Slaughter House', 'Type of Wastewater_Tannery',
#        'Type of Wastewater_Winery'],
#       dtype='object')

# %%
n = int(len(df1)*.9)-1
print(n)
df2=df1[:n]
x=df2.drop(['Effluent Conc. (mg/L)','Removal Efficiency (%)'],axis=1)
y=df2['Removal Efficiency (%)']
df3=df1[n:]
x1=df3.drop(['Effluent Conc. (mg/L)','Removal Efficiency (%)'],axis=1)
y1=df3['Removal Efficiency (%)']
# Out:
# 39

# %%
#Data processing functions
from sklearn.model_selection import train_test_split
#Regressor
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
 x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)

# %%
lm = LinearRegression() # Creating a Linear Regression object 'lm'
lm.fit(x_train,y_train)
predictions = lm.predict(x1)
print("Mean absolute error (MAE):", metrics.mean_absolute_error(y1,predictions))
print("Mean square error (MSE):", metrics.mean_squared_error(y1,predictions))
print("Root mean square error (RMSE):", np.sqrt(metrics.mean_squared_error(y1,predictions)))
print("R-squared value of predictions:",round(metrics.r2_score(y1,predictions),3))
# Out:
# Mean absolute error (MAE): 14.294278566748568
# Mean square error (MSE): 234.93578339061062
# Root mean square error (RMSE): 15.32761505879537
# R-squared value of predictions: 0.317

# %%
predictions_1 = lm.predict(x_test)
print("Mean absolute error (MAE):", metrics.mean_absolute_error(y_test,predictions_1))
print("Mean square error (MSE):", metrics.mean_squared_error(y_test,predictions_1))
print("Root mean square error (RMSE):", np.sqrt(metrics.mean_squared_error(y_test,predictions_1)))
print("R-squared value of validation:",round(metrics.r2_score(y_test,predictions_1),3))
# Out:
# Mean absolute error (MAE): 10.349506737785127
# Mean square error (MSE): 214.54661437930972
# Root mean square error (RMSE): 14.647409818097865
# R-squared value of validation: 0.646

# %%
from sklearn.svm import SVR

# %%
SVM = SVR(kernel="linear")
SVM.fit(x_train,y_train)
predictions = SVM.predict(x1)
print("Mean absolute error (MAE):", metrics.mean_absolute_error(y1,predictions))
print("Mean square error (MSE):", metrics.mean_squared_error(y1,predictions))
print("Root mean square error (RMSE):", np.sqrt(metrics.mean_squared_error(y1,predictions)))
print("R-squared value of predictions:",round(metrics.r2_score(y1,predictions),3))
# Out:
# Mean absolute error (MAE): 14.196319777147322
# Mean square error (MSE): 383.32178872214894
# Root mean square error (RMSE): 19.57860538246146
# R-squared value of predictions: -0.114

# %%
predictions_2 = SVM.predict(x_test)
print("Mean absolute error (MAE):", metrics.mean_absolute_error(y_test,predictions_2))
print("Mean square error (MSE):", metrics.mean_squared_error(y_test,predictions_2))
print("Root mean square error (RMSE):", np.sqrt(metrics.mean_squared_error(y_test,predictions_2)))
print("R-squared value of validation:",round(metrics.r2_score(y_test,predictions_2),3))
# Out:
# Mean absolute error (MAE): 16.1909710498068
# Mean square error (MSE): 632.9067200754147
# Root mean square error (RMSE): 25.15763741044486
# R-squared value of validation: -0.045

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
Model1 = RandomForestRegressor(n_estimators=1000,random_state=0,n_jobs=1000,max_depth=70,bootstrap=True)
Model1.fit(x_train,y_train)
predictions = Model1.predict(x1)
print("Mean absolute error (MAE):", metrics.mean_absolute_error(y1,predictions))
print("Mean square error (MSE):", metrics.mean_squared_error(y1,predictions))
print("Root mean square error (RMSE):", np.sqrt(metrics.mean_squared_error(y1,predictions)))
print("R-squared value of predictions:",round(metrics.r2_score(y1,predictions),3))
# Out:
# Mean absolute error (MAE): 10.841833333333348
# Mean square error (MSE): 223.3205918117362
# Root mean square error (RMSE): 14.94391487568556
# R-squared value of predictions: 0.351

# %%
predictions_3 = Model1.predict(x_test)
print("Mean absolute error (MAE):", metrics.mean_absolute_error(y_test,predictions_3))
print("Mean square error (MSE):", metrics.mean_squared_error(y_test,predictions_3))
print("Root mean square error (RMSE):", np.sqrt(metrics.mean_squared_error(y_test,predictions_3)))
print("R-squared value of validation:",round(metrics.r2_score(y_test,predictions_3),3))
# Out:
# Mean absolute error (MAE): 11.89650499999994
# Mean square error (MSE): 259.7081300973651
# Root mean square error (RMSE): 16.11546245372329
# R-squared value of validation: 0.571

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
Model2 = GradientBoostingRegressor()
Model2.fit(x_train,y_train)
predictions = Model2.predict(x1)
print("Mean absolute error (MAE):", metrics.mean_absolute_error(y1,predictions))
print("Mean square error (MSE):", metrics.mean_squared_error(y1,predictions))
print("Root mean square error (RMSE):", np.sqrt(metrics.mean_squared_error(y1,predictions)))
print("R-squared value of predictions:",round(metrics.r2_score(y1,predictions),3))
# Out:
# Mean absolute error (MAE): 11.597183276669645
# Mean square error (MSE): 290.29329902770036
# Root mean square error (RMSE): 17.037995745618097
# R-squared value of predictions: 0.156

# %%
predictions_4 = Model2.predict(x_test)
print("Mean absolute error (MAE):", metrics.mean_absolute_error(y_test,predictions_4))
print("Mean square error (MSE):", metrics.mean_squared_error(y_test,predictions_4))
print("Root mean square error (RMSE):", np.sqrt(metrics.mean_squared_error(y_test,predictions_4)))
print("R-squared value of validation:",round(metrics.r2_score(y_test,predictions_4),3))
# Out:
# Mean absolute error (MAE): 11.47931970087087
# Mean square error (MSE): 271.83648571254645
# Root mean square error (RMSE): 16.487464502237646
# R-squared value of validation: 0.551

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
Model3 = DecisionTreeRegressor( max_depth=100,
 max_features=1.0, max_leaf_nodes=10,min_samples_leaf=1,
 min_samples_split=2, min_weight_fraction_leaf=0.10,
 random_state=27, splitter='best')
Model3.fit(x_train,y_train)
predictions = Model3.predict(x1)
print("Mean absolute error (MAE):", metrics.mean_absolute_error(y1,predictions))
print("Mean square error (MSE):", metrics.mean_squared_error(y1,predictions))
print("Root mean square error (RMSE):", np.sqrt(metrics.mean_squared_error(y1,predictions)))
print("R-squared value of predictions:",round(metrics.r2_score(y1,predictions),3))
# Out:
# Mean absolute error (MAE): 12.702222222222224
# Mean square error (MSE): 372.0251407407406
# Root mean square error (RMSE): 19.287953254317593
# R-squared value of predictions: -0.082

# %%
predictions_5 = Model3.predict(x_test)
print("Mean absolute error (MAE):", metrics.mean_absolute_error(y_test,predictions_5))
print("Mean square error (MSE):", metrics.mean_squared_error(y_test,predictions_5))
print("Root mean square error (RMSE):", np.sqrt(metrics.mean_squared_error(y_test,predictions_5)))
print("R-squared value of validation:",round(metrics.r2_score(y_test,predictions_5),3))
# Out:
# Mean absolute error (MAE): 16.511388888888888
# Mean square error (MSE): 549.8704453703704
# Root mean square error (RMSE): 23.449316522456904
# R-squared value of validation: 0.092

# %%
from sklearn.ensemble import AdaBoostRegressor

# %%
Model4 = AdaBoostRegressor()
Model4.fit(x_train,y_train)
y_pred = Model4.predict(x_test)
predictions = Model4.predict(x1)
print("Mean absolute error (MAE):", metrics.mean_absolute_error(y1,predictions))
print("Mean square error (MSE):", metrics.mean_squared_error(y1,predictions))
print("Root mean square error (RMSE):", np.sqrt(metrics.mean_squared_error(y1,predictions)))
print("R-squared value of predictions:",round(metrics.r2_score(y1,predictions),3))
# Out:
# Mean absolute error (MAE): 10.752561274509809
# Mean square error (MSE): 206.53148555453438
# Root mean square error (RMSE): 14.371203343997829
# R-squared value of predictions: 0.4

# %%
predictions_6 = Model4.predict(x_test)
print("Mean absolute error (MAE):", metrics.mean_absolute_error(y_test,predictions_6))
print("Mean square error (MSE):", metrics.mean_squared_error(y_test,predictions_6))
print("Root mean square error (RMSE):", np.sqrt(metrics.mean_squared_error(y_test,predictions_6)))
print("R-squared value of validation:",round(metrics.r2_score(y_test,predictions_6),3))
# Out:
# Mean absolute error (MAE): 9.530654310966812
# Mean square error (MSE): 175.38305588678267
# Root mean square error (RMSE): 13.243226792847077
# R-squared value of validation: 0.71

# %%
# importing the libraries
from keras.models import Sequential
from keras.layers import Dense

# create ANN model
model = Sequential()

# Defining the Input layer and FIRST hidden layer, both are same!
model.add(Dense(units=5, input_dim=16, kernel_initializer='normal', activation='ELU'))

# Defining the Second layer of the model
# after the first layer we don't have to specify input_dim as keras configure it automatically
#model.add(Dense(units=5, kernel_initializer='normal', activation='tanh'))

# The output neuron is a single fully connected node
# Since we will be predicting a single number
model.add(Dense(1, kernel_initializer='normal'))

# Compiling the model
model.compile(loss='mean_squared_error', optimizer='adam')

# Fitting the ANN to the Training set
model.fit(x_train, y_train ,batch_size = 5, epochs = 400, verbose=1)
# Out:
# Epoch 1/400
# 6/6 [==============================] - 1s 3ms/step - loss: 7576.4404
# Epoch 2/400
# 6/6 [==============================] - 0s 2ms/step - loss: 7440.8340
# Epoch 3/400
# 6/6 [==============================] - 0s 2ms/step - loss: 7315.7793
# Epoch 4/400
# 6/6 [==============================] - 0s 2ms/step - loss: 7223.0347
# Epoch 5/400
# 6/6 [==============================] - 0s 2ms/step - loss: 7156.7031
# Epoch 6/400
# 6/6 [==============================] - 0s 3ms/step - loss: 7100.0249
# Epoch 7/400
# 6/6 [==============================] - 0s 2ms/step - loss: 7057.5615
# Epoch 8/400
# 6/6 [==============================] - 0s 2ms/step - loss: 7012.2524
# Epoch 9/400
# 6/6 [==============================] - 0s 2ms/step - loss: 6966.3594
# Epoch 10/400
# 6/6 [==============================] - 0s 3ms/step - loss: 6888.9028
# Epoch 11/400
# 6/6 [==============================] - 0s 2ms/step - loss: 6781.7979
# Epoch 12/400
# 6/6 [==============================] - 0s 4ms/step - loss: 6614.1406
# Epoch 13/400
# 6/6 [==============================] - 0s 3ms/step - loss: 6354.7622
# Epoch 14/400
# 6/6 [==============================] - 0s 2ms/step - loss: 6075.0156
# Epoch 15/400
# 6/6 [==============================] - 0s 3ms/step - loss: 5788.8770
# Epoch 16/400
# 6/6 [==============================] - 0s 3ms/step - loss: 5451.4634
# Epoch 17/400
# 6/6 [==============================] - 0s 3ms/step - loss: 5085.7729
# Epoch 18/400
# 6/6 [==============================] - 0s 2ms/step - loss: 4764.6440
# Epoch 19/400
# 6/6 [==============================] - 0s 3ms/step - loss: 4476.1494
# Epoch 20/400
# 6/6 [==============================] - 0s 2ms/step - loss: 4226.0728
# Epoch 21/400
# 6/6 [==============================] - 0s 3ms/step - loss: 4038.4668
# Epoch 22/400
# 6/6 [==============================] - 0s 3ms/step - loss: 3952.1138
# Epoch 23/400
# 6/6 [==============================] - 0s 2ms/step - loss: 3888.7234
# Epoch 24/400
# 6/6 [==============================] - 0s 3ms/step - loss: 3791.7141
# Epoch 25/400
# 6/6 [==============================] - 0s 3ms/step - loss: 3739.9202
# Epoch 26/400
# 6/6 [==============================] - 0s 2ms/step - loss: 3685.6753
# Epoch 27/400
# 6/6 [==============================] - 0s 2ms/step - loss: 3647.0903
# Epoch 28/400
# 6/6 [==============================] - 0s 3ms/step - loss: 3595.3975
# Epoch 29/400
# 6/6 [==============================] - 0s 3ms/step - loss: 3552.5745
# Epoch 30/400
# 6/6 [==============================] - 0s 3ms/step - loss: 3510.8967
# Epoch 31/400
# 6/6 [==============================] - 0s 2ms/step - loss: 3472.1909
# Epoch 32/400
# 6/6 [==============================] - 0s 3ms/step - loss: 3441.1062
# Epoch 33/400
# 6/6 [==============================] - 0s 2ms/step - loss: 3405.0093
# Epoch 34/400
# 6/6 [==============================] - 0s 4ms/step - loss: 3361.6650
# Epoch 35/400
# 6/6 [==============================] - 0s 3ms/step - loss: 3332.8923
# Epoch 36/400
# 6/6 [==============================] - 0s 2ms/step - loss: 3294.5823
# Epoch 37/400
# 6/6 [==============================] - 0s 2ms/step - loss: 3259.2019
# Epoch 38/400
# 6/6 [==============================] - 0s 2ms/step - loss: 3228.5620
# Epoch 39/400
# 6/6 [==============================] - 0s 2ms/step - loss: 3194.7522
# Epoch 40/400
# 6/6 [==============================] - 0s 2ms/step - loss: 3163.0232
# Epoch 41/400
# 6/6 [==============================] - 0s 3ms/step - loss: 3121.9746
# Epoch 42/400
# 6/6 [==============================] - 0s 3ms/step - loss: 
# 6/6 [==============================] - 0s 3ms/step - loss: 198.3403
# Epoch 379/400
# 6/6 [==============================] - 0s 3ms/step - loss: 198.0814
# Epoch 380/400
# 6/6 [==============================] - 0s 3ms/step - loss: 197.4411
# Epoch 381/400
# 6/6 [==============================] - 0s 3ms/step - loss: 194.0553
# Epoch 382/400
# 6/6 [==============================] - 0s 3ms/step - loss: 200.1848
# Epoch 383/400
# 6/6 [==============================] - 0s 3ms/step - loss: 194.6091
# Epoch 384/400
# 6/6 [==============================] - 0s 2ms/step - loss: 191.9035
# Epoch 385/400
# 6/6 [==============================] - 0s 3ms/step - loss: 190.2557
# Epoch 386/400
# 6/6 [==============================] - 0s 3ms/step - loss: 190.2952
# Epoch 387/400
# 6/6 [==============================] - 0s 3ms/step - loss: 185.9138
# Epoch 388/400
# 6/6 [==============================] - 0s 3ms/step - loss: 186.1266
# Epoch 389/400
# 6/6 [==============================] - 0s 3ms/step - loss: 184.7082
# Epoch 390/400
# 6/6 [==============================] - 0s 3ms/step - loss: 187.2847
# Epoch 391/400
# 6/6 [==============================] - 0s 3ms/step - loss: 183.4153
# Epoch 392/400
# 6/6 [==============================] - 0s 3ms/step - loss: 182.1905
# Epoch 393/400
# 6/6 [==============================] - 0s 4ms/step - loss: 181.4738
# Epoch 394/400
# 6/6 [==============================] - 0s 4ms/step - loss: 180.5131
# Epoch 395/400
# 6/6 [==============================] - 0s 3ms/step - loss: 179.1706
# Epoch 396/400
# 6/6 [==============================] - 0s 4ms/step - loss: 179.8118
# Epoch 397/400
# 6/6 [==============================] - 0s 4ms/step - loss: 178.3567
# Epoch 398/400
# 6/6 [==============================] - 0s 3ms/step - loss: 176.0431
# Epoch 399/400
# 6/6 [==============================] - 0s 4ms/step - loss: 175.0368
# Epoch 400/400
# 6/6 [==============================] - 0s 3ms/step - loss: 173.4892

# %%
predictions = model.predict(x1)
print("Mean absolute error (MAE):", metrics.mean_absolute_error(y1,predictions))
print("Mean square error (MSE):", metrics.mean_squared_error(y1,predictions))
print("Root mean square error (RMSE):", np.sqrt(metrics.mean_squared_error(y1,predictions)))
print("R-squared value of predictions:",round(metrics.r2_score(y1,predictions),3))
# Out:
# 1/1 [==============================] - 0s 107ms/step
# Mean absolute error (MAE): 14.069628041585288
# Mean square error (MSE): 362.1427517064199
# Root mean square error (RMSE): 19.030048652234704
# R-squared value of predictions: -0.053

# %%
predictions_7 = model.predict(x_test)
print("Mean absolute error (MAE):", metrics.mean_absolute_error(y_test,predictions_7))
print("Mean square error (MSE):", metrics.mean_squared_error(y_test,predictions_7))
print("Root mean square error (RMSE):", np.sqrt(metrics.mean_squared_error(y_test,predictions_7)))
print("R-squared value of validation:",round(metrics.r2_score(y_test,predictions_7),3))
# Out:
# 1/1 [==============================] - 0s 31ms/step
# Mean absolute error (MAE): 19.627819697062176
# Mean square error (MSE): 574.2350585274618
# Root mean square error (RMSE): 23.963202175991874
# R-squared value of validation: 0.052

# %%
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6))= plt.subplots(nrows=2, ncols=3, figsize=(14,14))
ax = sns.regplot(x=predictions_1, y=y_test, scatter= True, fit_reg= True,ax=ax1)
ax.set(xlabel='Predicted',ylabel='Actual',title='Linear Regression')

ax = sns.regplot(x=predictions_2, y=y_test, scatter= True, fit_reg= True,ax=ax2)
ax.set(xlabel='Predicted',ylabel='Actual',title='Support Vector Regressor')

ax = sns.regplot(x=predictions_3, y=y_test, scatter= True, fit_reg= True, ax=ax3)
ax.set(xlabel='Predicted',ylabel='Actual',title='Random Forest Regressor')

ax = sns.regplot(x=predictions_4, y=y_test, scatter= True, fit_reg= True, ax=ax4)
ax.set(xlabel='Predicted',ylabel='Actual',title='Gradient Boosting Regressor')

ax = sns.regplot(x=predictions_5, y=y_test, scatter= True, fit_reg= True, ax=ax5)
ax.set(xlabel='Predicted',ylabel='Actual',title='Decision Tree')

ax = sns.regplot(x=predictions_6, y=y_test, scatter= True, fit_reg= True, ax=ax6)
ax.set(xlabel='Predicted',ylabel='Actual',title='Adaptive Boosting')
# Out:
# [Text(0.5, 0, 'Predicted'),
#  Text(0, 0.5, 'Actual'),
#  Text(0.5, 1.0, 'Adaptive Boosting')]

# %%
features =Model4.feature_importances_
Columns = list(x.columns)
for i,j in enumerate(features):
    print(Columns[i],"->",j)
plt.figure(figsize=(16,5))
plt.title(label="GBR")
#plt.xlabel('C (%)','H (%)','N (%)','O (%)','T (°C)','RT (min)','HR (°C/min)')
plt.bar([x for x in range(len(features))],features)
plt.show()
# Out:
# Temperature (C) -> 0.047391402406490896
# pH -> 0.2500046004376712
# VF Area (m2) -> 0.03407673841182781
# HF Area (m2) -> 0.059654480865495955
# HRT (d) -> 0.05068127531554658
# HLR (L/m2d) -> 0.05443998983103284
# Q (flow) (m3/d) -> 0.07224329311121475
# Influent Conc. (mg/L) -> 0.15066444468340096
# Type of Wastewater_Aquaculture -> 0.09629871256636877
# Type of Wastewater_Cheese -> 0.034473994928793154
# Type of Wastewater_Domestic Wastewater -> 0.0
# Type of Wastewater_Landfill leachate -> 0.03728058933559354
# Type of Wastewater_Sewage -> 0.10612128473429927
# Type of Wastewater_Slaughter House -> 0.0
# Type of Wastewater_Tannery -> 0.0004374871754140468
# Type of Wastewater_Winery -> 0.006231706196850155

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

frequencies = []
x_labels = []
Columns = list(x.columns)
for i,j in enumerate(features):
    frequencies.append(j)
    x_labels.append(Columns[i])

freq_series = pd.Series(frequencies)


# Plot the figure.
plt.figure(figsize=(12, 8))
fig = freq_series.plot(kind='bar')
fig.set_xticklabels(x_labels)
# Out:
# [Text(0, 0, 'Temperature (C)'),
#  Text(1, 0, 'pH'),
#  Text(2, 0, 'VF Area (m2)'),
#  Text(3, 0, 'HF Area (m2)'),
#  Text(4, 0, 'HRT (d)'),
#  Text(5, 0, 'HLR (L/m2d)'),
#  Text(6, 0, 'Q (flow) (m3/d)'),
#  Text(7, 0, 'Influent Conc. (mg/L)'),
#  Text(8, 0, 'Type of Wastewater_Aquaculture'),
#  Text(9, 0, 'Type of Wastewater_Cheese'),
#  Text(10, 0, 'Type of Wastewater_Domestic Wastewater'),
#  Text(11, 0, 'Type of Wastewater_Landfill leachate'),
#  Text(12, 0, 'Type of Wastewater_Sewage'),
#  Text(13, 0, 'Type of Wastewater_Slaughter House'),
#  Text(14, 0, 'Type of Wastewater_Tannery'),
#  Text(15, 0, 'Type of Wastewater_Winery')]
